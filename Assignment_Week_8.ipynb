# %% [markdown]
# Add the following libraries:

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
np.random.seed(0)

# %% [markdown]
# The following line makes 4 blobs with 5000 samples, and you can adjust the centers and the standard deviation with the parameters.

# %%
X, y = make_blobs(n_samples=5000, centers=[[4,4], [-2, -1], [2, -3], [1, 1]], cluster_std=0.9)
plt.scatter(X[:, 0], X[:, 1], marker='.')

# %% [markdown]
# The following lines work by applying KMeans and obtaining the labels and centers from the algorithm.

# %%
k_means = KMeans(init = "k-means++", n_clusters = 2, n_init = 12)
k_means.fit(X)
k_means_labels = k_means.labels_
k_means_cluster_centers = k_means.cluster_centers_

# %% [markdown]
# The following lines display the results from the KMeans and how they clustered the data

# %%
fig = plt.figure(figsize=(6, 4))
colors = plt.cm.Spectral(np.linspace(0, 1, len(set(k_means_labels))))
ax = fig.add_subplot(1, 1, 1)
for k, col in zip(range(len([[4,4], [-2, -1], [2, -3], [1, 1]])), colors):
       my_members = (k_means_labels == k)
       cluster_center = k_means_cluster_centers[k]
       ax.plot(X[my_members, 0], X[my_members, 1], 'w', markerfacecolor=col, marker='.')
       ax.plot(cluster_center[0], cluster_center[1], 'o', markerfacecolor=col, markeredgecolor='k', markersize=6)

# %% [markdown]
# Find out where in the code you need to change to improve the KMeans. Remember, there are 4 blobs!

# %%
X, y = make_blobs(n_samples=5000, centers=[[4,4], [-2, -1], [2, -3], [1, 1]], cluster_std=0.9)
plt.scatter(X[:, 0], X[:, 1], marker='.')
#The following lines work by applying KMeans and obtaining the labels and centers from the algorithm.
k_means = KMeans(init = "k-means++", n_clusters = 4, n_init = 12)
k_means.fit(X)
k_means_labels = k_means.labels_
k_means_cluster_centers = k_means.cluster_centers_
#The following lines display the results from the KMeans and how they clustered the data
fig = plt.figure(figsize=(6, 4))
colors = plt.cm.Spectral(np.linspace(0, 1, len(set(k_means_labels))))
ax = fig.add_subplot(1, 1, 1)
for k, col in zip(range(len([[4,4], [-2, -1], [2, -3], [1, 1]])), colors):
       my_members = (k_means_labels == k)
       cluster_center = k_means_cluster_centers[k]
       ax.plot(X[my_members, 0], X[my_members, 1], 'w', markerfacecolor=col, marker='.')
       ax.plot(cluster_center[0], cluster_center[1], 'o', markerfacecolor=col, markeredgecolor='k', markersize=6)

# %% [markdown]
# Repeat for blobs with a standard deviation of 3.0 (for the remaining parameters use the initial configuration).

# %%
X, y = make_blobs(n_samples=5000, centers=[[4,4], [-2, -1], [2, -3], [1, 1]], cluster_std=3.0)
plt.scatter(X[:, 0], X[:, 1], marker='.')
#The following lines work by applying KMeans and obtaining the labels and centers from the algorithm.
k_means = KMeans(init = "k-means++", n_clusters = 2, n_init = 12)
k_means.fit(X)
k_means_labels = k_means.labels_
k_means_cluster_centers = k_means.cluster_centers_
#The following lines display the results from the KMeans and how they clustered the data
fig = plt.figure(figsize=(6, 4))
colors = plt.cm.Spectral(np.linspace(0, 1, len(set(k_means_labels))))
ax = fig.add_subplot(1, 1, 1)
for k, col in zip(range(len([[4,4], [-2, -1], [2, -3], [1, 1]])), colors):
       my_members = (k_means_labels == k)
       cluster_center = k_means_cluster_centers[k]
       ax.plot(X[my_members, 0], X[my_members, 1], 'w', markerfacecolor=col, marker='.')
       ax.plot(cluster_center[0], cluster_center[1], 'o', markerfacecolor=col, markeredgecolor='k', markersize=6)

# %% [markdown]
# Repeat for 5 blobs. That means, creating five blobs (one centered in [0,0]) and using KMeans to divide them  (for the remaining parameters use the initial configuration).

# %%
X, y = make_blobs(n_samples=5000, centers=[[0,0],[4,4], [-2, -1], [2, -3], [1, 1]], cluster_std=0.9)
plt.scatter(X[:, 0], X[:, 1], marker='.')
#The following lines work by applying KMeans and obtaining the labels and centers from the algorithm.
k_means = KMeans(init = "k-means++", n_clusters = 5, n_init = 12)
k_means.fit(X)
k_means_labels = k_means.labels_
k_means_cluster_centers = k_means.cluster_centers_
#The following lines display the results from the KMeans and how they clustered the data
fig = plt.figure(figsize=(6, 4))
colors = plt.cm.Spectral(np.linspace(0, 1, len(set(k_means_labels))))
ax = fig.add_subplot(1, 1, 1)
for k, col in zip(range(len([[4,4], [-2, -1], [2, -3], [1, 1]])), colors):
       my_members = (k_means_labels == k)
       cluster_center = k_means_cluster_centers[k]
       ax.plot(X[my_members, 0], X[my_members, 1], 'w', markerfacecolor=col, marker='.')
       ax.plot(cluster_center[0], cluster_center[1], 'o', markerfacecolor=col, markeredgecolor='k', markersize=6)

# %% [markdown]
# Repeat for a smaller make_blobs sample.

# %%
X, y = make_blobs(n_samples=3000, centers=[[0,0],[4,4], [-2, -1], [2, -3], [1, 1]], cluster_std=0.9)
plt.scatter(X[:, 0], X[:, 1], marker='.')
#The following lines work by applying KMeans and obtaining the labels and centers from the algorithm.
k_means = KMeans(init = "k-means++", n_clusters = 5, n_init = 12)
k_means.fit(X)
k_means_labels = k_means.labels_
k_means_cluster_centers = k_means.cluster_centers_
#The following lines display the results from the KMeans and how they clustered the data
fig = plt.figure(figsize=(6, 4))
colors = plt.cm.Spectral(np.linspace(0, 1, len(set(k_means_labels))))
ax = fig.add_subplot(1, 1, 1)
for k, col in zip(range(len([[4,4], [-2, -1], [2, -3], [1, 1]])), colors):
       my_members = (k_means_labels == k)
       cluster_center = k_means_cluster_centers[k]
       ax.plot(X[my_members, 0], X[my_members, 1], 'w', markerfacecolor=col, marker='.')
       ax.plot(cluster_center[0], cluster_center[1], 'o', markerfacecolor=col, markeredgecolor='k', markersize=6)
